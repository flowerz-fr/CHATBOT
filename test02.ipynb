# %%
from BlobStorage import AzureBlobStorageDownloader
from BlobStorage import AzureBlobContainer


azure_blob_storage = AzureBlobContainer()
azure_blob_storage.list_blobs_flat()
azure_blob_storage.download_all_blobs_in_container()
# Out:
# Name: PDF/DEG/ELH-2018-022986.pdf, Tags: None, Metadata: {'perimeter': 'DEG', 'investigations_number': 'ELH-2018-022986.pdf', 'docType': 'pdf', 'year': '2018'}
# Name: PDF/DEG/ELH-2019-014855.pdf, Tags: None, Metadata: {'perimeter': 'DEG', 'investigations_number': 'ELH-2019-014855.pdf', 'docType': 'pdf', 'year': '2019'}
# Name: PDF/DEG/ELH-2019-017580.pdf, Tags: None, Metadata: {'perimeter': 'DEG', 'investigations_number': 'ELH-2019-017580.pdf', 'docType': 'pdf', 'year': '2019'}
# Name: PDF/DEG/ELH-2019-022027.pdf, Tags: None, Metadata: {'perimeter': 'DEG', 'investigations_number': 'ELH-2019-022027.pdf', 'docType': 'pdf', 'year': '2019'}
# Name: PDF/DEG/ELH-2019-027845.pdf, Tags: None, Metadata: {'perimeter': 'DEG', 'investigations_number': 'ELH-2019-027845.pdf', 'docType': 'pdf', 'year': '2019'}
# Name: PDF/DEG/ELH-2020-033633.pdf, Tags: None, Metadata: {'perimeter': 'DEG', 'investigations_number': 'ELH-2020-033633.pdf', 'docType': 'pdf', 'year': '2020'}
# ...
